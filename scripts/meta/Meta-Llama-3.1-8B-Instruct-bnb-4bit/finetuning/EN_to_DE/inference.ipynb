# %% [markdown]
# # Import libraries

# %%
import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"
import time
import pandas as pd
#import torch

from huggingface_hub import login
from datasets import load_dataset
from unsloth import FastLanguageModel
from unsloth import is_bfloat16_supported
from peft import PeftModel
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %% [markdown]
# # Set Paths and Hyperparameters

# %%
# Base path
base_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..', '..', '..'))

# Best model stored under
best_model = "epoch_2"

# Source and target language
source_language = "English"
target_language = "Early Modern Bohemian German"

# Translation direction
translation_direction = "DE_to_EN" if source_language == "Early Modern Bohemian German" else "EN_to_DE"

# Model parameters
unsloth_model_name = 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit'
company_name = 'meta'

model_name = unsloth_model_name.split('/')[1]
max_new_tokens = 5000           # Maximum number of model output
max_seq_length = 128000         # Maximum of input tokens
dtype = None                    # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True             # Use 4bit quantization to reduce memory usage. Can be False.

# Load lora model from path
load_lora_model_path = os.path.join(
    base_path, 
    'models', 
    company_name, 
    model_name, 
    'finetuning', 
    translation_direction, 
    best_model)

# Save inference dataset
save_path = os.path.join(
    base_path, 
    'results', 
    company_name,
    model_name, 
    'finetuning', 
    translation_direction, 
    f'{translation_direction}_finetuning.json'
)

# Print paths
print(f'Company name: {company_name}')
print(f'Model name: {model_name}')
print(f'Base path: {base_path}')
print(f'Translation direction: {translation_direction}')
print(f'LoRA model path: {load_lora_model_path}')
print(f'Save finetuning inference dataset path: {save_path}')

# Hugging face login
hub_token = "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"
login(hub_token, add_to_git_credential=True)
# Out:
# Company name: meta
# Model name: Meta-Llama-3.1-8B-Instruct-bnb-4bit
# Base path: /cs/student/msc/csml/2023/ngriessh/historical_mt
# Translation direction: EN_to_DE
# LoRA model path: /cs/student/msc/csml/2023/ngriessh/historical_mt/models/meta/Meta-Llama-3.1-8B-Instruct-bnb-4bit/finetuning/EN_to_DE/epoch_2
# Save finetuning inference dataset path: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Meta-Llama-3.1-8B-Instruct-bnb-4bit/finetuning/EN_to_DE/EN_to_DE_finetuning.json
# Token is valid (permission: write).
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /cs/student/msc/csml/2023/ngriessh/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Load Dataset & ICL examples

# %%
# Load test dataset
dataset = load_dataset('niclasgriesshaber/EarlyModernGerman_to_EN_finetuning')
test_dataset = dataset['test']
print(f'Loaded test dataset: \n {test_dataset}')
# Out:
# Loaded test dataset:
#  Dataset({
#     features: ['Early Modern Bohemian German', 'English'],
#     num_rows: 1000
# })

# %% [markdown]
# # Prompt template

# %%
# Prompt template
prompt_template = """<|begin_of_text|><|start_header_id|>system<|end_header_id|>

You are a helpful assistant tasked with translating from {} to {}. NEVER provide an introduction to the translation (e.g. 'Here is the translation:', 'Translate to', 'Hier ist die Übersetzung:', etc.), explanations or clarifications.
NEVER provide a note after your translation.<|eot_id|>
<|start_header_id|>user<|end_header_id|>

### Translation Task. Only translate the following text. Nothing else!

{}:
{}

Translate to {} and match the structure of the source text. Output only this translation and nothing else.<|eot_id|>
<|start_header_id|>assistant<|end_header_id|>{}"""

# %%
# Apply prompt template to test dataset
def formatting_prompts_func(examples, source_language, target_language):
    
    source_texts = examples[source_language]
    texts = []

    for source_text in source_texts:
        # Format the prompt with dynamic source and target languages
        text = prompt_template.format(
            source_language,  # Dynamic source language
            target_language,  # Dynamic target language
            source_language,  # Target language for translation request
            source_text,      # Actual source text to translate
            target_language,  # Target language for translation output (no actual output included)
            ""                # Placeholder for the output, left empty for inference
        )
        texts.append(text)

    return {"text": texts}

# %% [markdown]
# # Apply Prompt Template to Test Dataset

# %%
# Apply prompt template to all test samples
test_dataset = test_dataset.map(
    lambda examples: formatting_prompts_func(examples, source_language, target_language),
    batched=True
)

# %%
# Output a text file to check prompt
with open('inference_prompt_check', "w") as f:
    f.write(test_dataset['text'][0])

# %% [markdown]
# # Load Model

# %%
# Load model and tokenizer
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=unsloth_model_name,
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.9.post4: Fast Llama patching. Transformers = 4.44.2.
#    \\   /|    GPU: NVIDIA GeForce RTX 3090 Ti. Max memory: 23.575 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.4.1+cu121. CUDA = 8.6. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.28.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth

# %% [markdown]
# # Load LoRA adapters

# %%
# Load LoRA adapters from Peft
print('Loading LoRA adapaters')
model = PeftModel.from_pretrained(model, load_lora_model_path)
print('LoRA adapters loaded successfully')
print(f'Lora model path under: {load_lora_model_path}')
# Out:
# Loading LoRA adapaters
# LoRA adapters loaded successfully
# Lora model path under: /cs/student/msc/csml/2023/ngriessh/historical_mt/models/meta/Meta-Llama-3.1-8B-Instruct-bnb-4bit/finetuning/EN_to_DE/epoch_2

# %% [markdown]
# # Inference

# %%
# Set model to inference mode
FastLanguageModel.for_inference(model)
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaExtendedRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Identity()
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=14336, out_features=16, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=16, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %%
# Save inferences in new dataset
def process_dataset(test_dataset, model, tokenizer, max_new_tokens, translation_direction):

    # Extract target language
    if translation_direction == "DE_to_EN":
        target_language = "English"
    else:
        target_language = "Early Modern Bohemian German"
    
    # Convert Hugging Face dataset to Pandas DataFrame
    df = pd.DataFrame(test_dataset)
    
    total_time = 0  # Initialize the total time accumulator

    # Loop through each row in the dataframe
    for i, row in df.iterrows():
        start_time = time.time()  # Start timer for the current inference

        try:
            print(f"Processing test point {i + 1} of {len(df)}")

            # Get the text for the current row
            inputs = tokenizer([row['text']], return_tensors="pt").to("cuda")

            # Generate the model outputs
            outputs = model.generate(**inputs, max_new_tokens=max_new_tokens, use_cache=True)

            # Decode the outputs, converting from token IDs back to text
            decoded_outputs = tokenizer.batch_decode(outputs, skip_special_tokens=False)

            # Since decoded_output has only one entry, extract the single output
            output = decoded_outputs[0]

            # Define the exact substring to search for
            search_string = f"<|start_header_id|>assistant<|end_header_id|>"

            # Find the index of the search_string in the output
            start_idx = output.find(search_string)

            # Extract everything after the search_string if it's found
            if start_idx != -1:
                extracted_text = output[start_idx + len(search_string):]
            else:
                extracted_text = 'NA'

            # Manually remove the special token '<|eot_id|>' from the beginning and the end, if present
            extracted_text = extracted_text.replace("<|start_header_id|>assistant<|end_header_id|>", "").strip()
            extracted_text = extracted_text.replace("<|eot_id|>", "").strip()

            # Print the output and extracted text
            print('_________________________________________________')
            print(test_dataset[target_language][i])
            print('_________________________________________________')
            print(extracted_text)
            print('_________________________________________________')

            # Add extracted_text directly to the dataframe at index i
            df.at[i, f'{translation_direction}_finetuning'] = extracted_text

        except Exception as e:
            print(f"Error occurred at test point {i + 1}: {str(e)}")
        
        end_time = time.time()  # End timer for the current inference
        elapsed_time = end_time - start_time  # Calculate elapsed time
        total_time += elapsed_time  # Accumulate total time

        print(f"Time for test point {i + 1}: {elapsed_time:.2f} seconds, Total time: {total_time:.2f} seconds")

    return df

# %%
# Call the function
processed_dataset = process_dataset(test_dataset, model, tokenizer, max_new_tokens, translation_direction)

# Save the dataset as a JSON file
processed_dataset.to_json(save_path, orient='records', lines=True, force_ascii=False)
print(f"Dataset saved successfully to {save_path}")
# Out:
# Processing test point 1 of 1000
# _________________________________________________
# Demnach das flößholz nicht gespaltten Sollen derwegen solches von dato in 14. tagen entlichen vnd ohn allen Verzug spaltten bey der Peen 1 Weiß schock, Signatum den 3.Octobris A. 88.
# _________________________________________________
# Demnach sie das floß holtz nit gespalten Sollen sie derenthalben solches von dato in 14 tagen Vnd Vnn Verzügliche Vrsach Vnd ohn alle Vormittlung spalten bey der Peen 1 w. sß Signatum den 3 Octobris Ao. 88.
# _________________________________________________
# Time for test point 1: 1.79 seconds, Total time: 1.79 seconds
# Processing test point 2 of 1000
# _________________________________________________
# Demnach Christoff Brohtsacks Tochter zue lüesdorff Von hanßen Apelt auf der Weispach, bey deme sie gedient geschwengert, Vnd dieserhalb. gefenglich. eingezogen worden, Weill dan sie burg.n sezen sollen, sich auf ehestes erfordern hinweid.umb zugestellen, aber sich niemandt vor sie bürglich. einlaßen wollen, hat doch der Vater angelobet, bej strafe des gefengnußes, sie auf ehestes begehren ins Ambt zugestellen, Actum.11. xbris. Ao. 610.
# _________________________________________________
# Demnach Christoff Brohtsacks Tochter Zue Luesdorf, Von hanß Apeltten Zue Weyßpach mit dem sie gedienet, geschwengert Worden, Vndt derenthalben gefenglich eingezogen Worden, Weiln sie aber sich wieder auf ehestes erfordern Zue gestellen, burgen seint sollen, Jedoch Niemandt sich Vor sie in burgschaft eingelassen, hat aber der Vater angelobet, sie auff ehestes erfordern, bey straff des gefengnußes, ins Ambt Zue gestellen Actum den 11 xbris Ao 610.
# _________________________________________________
# Time for test point 2: 2.58 seconds, Total time: 4.38 seconds
# Processing test point 3 of 1000
# _________________________________________________
# George wiesener leinweber zue Newstadt hat bey Ihr. gn: supplicando ansuchung gethan das ihne möchte vorgönet werden möchte, dan her Johan Christan wolten dießelbe wahren nicht Kaufen, das sie ihre leimet ihrer gelegenheit nach Vorkauffen möchte
# _________________________________________________
# George Wiesener Leinweber Zur Neustadt Haben bey V. gn. Suppliciert, das ihnen in gnaden verlaubet werde, sintemahlen Ihr. Gn: Johan Christan Ihre wahren nicht Kauffen wolten, das sie Ihr Leinwadt nach ihren gelegenheit Vorkauffen möchten.
# _________________________________________________
# Time for test point 3: 1.31 seconds, Total time: 5.69 seconds
# Processing test point 4 of 1000
# _________________________________________________
# Demnach Er wegen Etlicher gemachter schulden, gefengklich Eingezogen, Vnd der gestaldt widerumb der gefengknus Entledigt, das Er sich Zwischen hier Vnd faßnacht, mit All seinen glaubiger, Richtig Abfind. Vnd vertragen solle, Imm fall Es aber nicht bescheh, Vnd nach außgang dießer Zeitt, sich seine glaubiger, weg. nicht Zahlung, hinwider angeben würden. Solle Ihne nachbemelter burg, hinwieder An die Ortt Vnd stelle darauß Er An Jetzo gelassen, Zue gestellen schuldig sein da dann vermöge deß herrn S. G. gemachte Ordnung, was Recht ist Ergehen solle darfur Ist burg Paul hubner Zu bernßdorff, Act. fridlandt am Jar dieng den 16. January. Ao. 85.
# _________________________________________________
# Demnach er wegen etzlicher schuld in gefenckliche hafft eingezogen, Ist er Zu Pürgen wieder heraus geben worden, das er sich Zwischen hier vnd Fasten mit allen seinen schuldig. richtig vnd richtig machen soll, da er aber solches nit thut, sol ihn sein Purge wieder herauß gestellen vnd er sich des herrn S. G. Ordnung vnderthenig sein, Purge Paul hubner von Bernßdorff, Signat: Fridlandt am Jahrding den 16 January A.o 85.
# _________________________________________________
# Time for test point 4: 2.23 seconds, Total time: 7.92 seconds
# Processing test point 5 of 1000
# _________________________________________________
# Simon Bruß, wolff walter, Christoff herwig Vnd Anthoni Mentzel alle von Mildenaw, demnach sie sich auf des herrn S. G. befehl, wie ihnen der Burg graf eingebietten lassen in die gerichte nit gestanden, sondern alle vngehorsamlich aussenblieben, derenthalb: sie in gefencklicher hafft eingezogen, vnd widrumb das sie forthin deßen gehorsamer sein sollen, herauß gelassen werden, vnd auf erforderung widrumb gestellen, bei harter straff, Sig: den 27 July A.o 85.
# _________________________________________________
# Simon bruss, wolf walter, Christof herwig vnd Anthoni metzel alle von Mildenaw, demnach sie auff beuehl des herrn S. G. In die gerichte erfordertt nit Kommen, sondern vngehorsamlich Außenblieben, derenthalben sie gefenglich eingezogen worden, deßelben aber Zu Pürgen wiederumb herauß geben, der gestaldt, das sie sich Künfftig Vormehr gehorsamlich Vorhalten, vnd auff erfoderung sich gestellen sollen, bey hartter straf, Signat: den 27 July A.o 85.
# _________________________________________________
# Time for test point 5: 2.53 seconds, Total time: 10.45 seconds
# Processing test point 6 of 1000
# _________________________________________________
# Demnach Alß sie Mutwilliger weise zu keiner Zeit das holz gespalten Vnd dem burggrafen gewehret sint sie derenthalben gefenglich eingezogen Vnd zu Purgen wiederumb außgeben der gestald vnd Also das sie das holz denen burggrafen vber Acht tage gewehren sollen bei d. Peen 50 sß. da fur Ist Purge lucas Apel. Signatum Fridlandt den 7 december A. 91.
# _________________________________________________
# Demnach sie das holz muttwillig nit gespalten Vnd dem burggraffen nit gestanden, sint sie derenthalben gefenglich eingezogen Vnd Zu Pürgen wieder herauß geben Worden, der gestaldt Vnd Also, das sie dem burggraff das holz in Achtagen Zuuorhaiden soll, bey der Peen 50 sß dafür ist Pürge Lucas Apel, Signat: Fridlandt den 7. Decemb: A. 91.
# _________________________________________________
# Time for test point 6: 1.99 seconds, Total time: 12.44 seconds
# Processing test point 7 of 1000
# _________________________________________________
# George Jackel ist anderweidt wegen des diebstahls befraget worden saget aus, das einste mahl wehre Vor drey wochen geschehen wehre ettwan ein quarters geweßen, Andelman wehre erstlichen Zu ihnen Kommen, vnd es angebracht, sie wollen ein wenig machen, was ehr gestern aus gesagt bey denselb. berichtet ehr beständiglichen. 3. izige getreide Kan ehr nicht wißen wieuiel deßelb. geweßen, das es noch in die Teilung Kommen solle, stehet in des Rugk Cammer. George Jäckel berichtet ehr habe Funff Kinder was geschehen, wehre des Kummer halb. geschehen, Antellman hette gesagt sie wollen ein bißell nehmen.
# _________________________________________________
# George Jackel ist abermahl Vber den diebstahl befraget worden, saget aus, es wehre Vor drey wochen geschehen, Es wehre Andelman zu ihm Kommen, es Vorbracht, sie wolten ein wenig machen, berichtet bestendig was ehr gestriges Tages bej ihme aus gesagt. das ieztige getreide wuste ehr nicht wie Viel wehre weill es noch Vorteillich. stünde in der hinderstube. George Jaeckel berichtet, ehr hette.5. Kinder, wehre Vmb die sorge geschehen, es hette Antellman gesagt sie wolten ein wenig nehmen.
# _________________________________________________
# Time for test point 7: 2.71 seconds, Total time: 15.15 seconds
# Processing test point 8 of 1000
# _________________________________________________
# Demnach Chabig Richters tochter Vndt die Eltesten 2 Söhne gegen Mathes Pilzen Von Ringenhain mit allerley vngebührlich. Vndt Schmehlichen Wortten, auch mitt VnZüchtigen geberdenen daß mit trotzigen drew worten sich erZeigett, das Mathes Pilz geZwung. worden, solchs beym Ambt Zu klagen, Als ist Chabig Richter der Vatter, weil er seinen Kindern solchen Muttwillen ganz Vngestrafft hinpassiren lasset, sie hierinnen noch Vorteidigen Vndt stercken wollen, derentweg. sambt dem einen Sohne mitt gefengnuß gestrafft, Vndt nach erledigung beym Ampt angelobet, sambt seinem Aidam Bartell Jemigen des er Künfftig seinen Kindern solchen Muttwillen ferner nit gestatten sich auch sampt demselben geg. Mathes Pelzen Vndt desselben Kindern Vnd Gesinde nichts Vngebührliches erzeigen wolle Bey straff der herrschafft Ainhundertt sß. Zu erlegen, dafür er mitt seinem guttern Vndt sein Aidam neben ihme Zuhafften angelobet, Actum im Ampt Friedlandt den 25 Augustj Ao 1604
# _________________________________________________
# Demnach Fabius Richters Tochter Vnd die Eltesten Zwo Söhne gegen Mathes Pilzen Von Ringenhain mit allerhandt Vngebührlich Vnd Schmehewortten, Auch mit Vnniederlichen gesten mit Vornehmen drohungen, so das Mathes Pilz sich deßweg. im Ampt beschweren mußen, Vnd darumb Fabius Richter der Vatter, Weil er solche Muttwilligkeit Von seinen Kindern ganz Vnn gestrafft, Vnd sie darbej noch Vorwehren Vndt Vorschreiben Will, derenthalben er sambt seinem Sohn mit gefengnus gestrafft, Vnd nach erledigung im Ampt anglobet, sambt seinem Aidam Bartell Jemigen, sich Künfftig solche Muttwilligkeit bey seinen Kindern nicht weiter Zulaßen, Auch gegen Mathes Pelzen Vndt deßen Kindern Vnd gesindel nichts Vngebührlich Zutun, bej straff der herrschafft 100 sß, so er bey seinen gutten Vndt seinem Aidam neben sich Zuuorburgen, Actum im Ampt Friedlandt den 25 Augustij Ao 1604.
# _________________________________________________
# Time for test point 8: 4.85 seconds, Total time: 20.00 seconds
# Processing test point 9 of 1000
# _________________________________________________
# Frantz Von Schwantz Zu Arnsdorff beschweret sich Vber Nicol Olsnern, weil ehr aufn abendt mit zweien pferden zu ihme komen, Vnd ihme eines, benebenst Sembdnern angebohten, Hierauff ihnen der Jünckern angemeldet, sie soltten morg. wied. kommen, ehr köndte das pferdt nicht anschauen, Hierauf sie geandtworttet sie soltten morg. ins Sielautsche reitten. Nachmals wie sie ihme das pferdt sehr eingelobet, Hette ehr daßselbe Vntter licht in stall fuhren laßen, Vnd ihnen noch hew vnd hafer, geben laßen, auch eßen, vnd Trüncken, Vnd ihnen darneben seine.2. pferde Vor das eine geben vnd.2. Tal darkeg. sie ihme daßelbe auf.4. wochen gewahren wollen, Alsobaldt des andern Tags hette ehr gesehen, das ihme das pferdt wenig nuze, Vnd alsobald zu Olsner geschickt das ehr sein pferd wied. nehmen, oder zu ihme Kommen soltte, vnd sich mit ihme des betrugß halben, abfindig machen, sie wehren albereidt vnd also bald hinweg geritten, Vnd die beid. pferde Vorkaufft. Vnd ob ehr wohl Sie ezlichen mahlen zu ihme geschickt nach Rückersdorff, ehr ihme auch zuentbieten laßen, wie ehr zu ihme Kommen woltte, denselbig. aber hette ehr Keine Volge geleistet. Bittet Vmb erstattüng des zugefügten betrugß, vnd schadens, Olsner andtworttet, an beid. pferden wehre auch nichts guts geweßen, ehr hette Kein Futter gehabt, deroweg. ehr die beiden pferde Vorkauffen mußen.
# _________________________________________________
# Frantz von Schwantz Zu Arnsdorff Klagt Vber Nicol Olsnern, wie ehr auff einen abendt mit Zweien pferden Zu ihme kommen, ihme eines anbotten, nebenst, darauff der Junckern ihnen gesagt, sie solten aufm morg. Kommen, ehr Köndte das pferdt nicht besichtigen, hierauff sie geandtworttet, sie solten morg. in die Sielautsche reitten, Nachmals wie sie das pferdt hoch gelobet, hette ehr es in die stalle Vntter leuchter führen laßen, ihme auch hew Vnd haw gefodert, ehr auch 2 pferde Vor das eine geben, Vnd 2 thaler daruohr sie ihme Vor 4. wochen hette Zuegesagt, Als hette ehr als baldt morg. gesehen, das ihme das pferdt wenig nuz geweßen, als baldt nach Olsnern geschickt, das ehr ihme sein pferdt wieder nehmen solle, oder ehr zu ihme Kommen, Vnd sich mit ihme wegen des betrieges Vortragen, wehren als baldt Vnd alsobaldt weggereitten, Vnd die beide pferde VorKaufft, Vnd ob ehr ihnen Zue Rückersdorff Viel mahl geschickt, ihnen auch Viel mahl beuohlen, aufs sein Zu Kommen, Habe ehr doch daran nichts nachgelebt. Bittet Vmb ersezung des geschehenen betrieges, Vnd schaden. R.sndet Olsner, es wehre bej beidem pferden nichts guts geweßen, hette Keinen futter, daraus wehre ehr beide pferde Vor Kauffen mußen.
# _________________________________________________
# Time for test point 9: 7.53 seconds, Total time: 27.53 seconds
# Processing test point 10 of 1000
# _________________________________________________
# Der hoff Müller Geörg wendwich, hat daß Alte Lehen strichteichel vnterm Scholtzen, bej der dürden Zeitt, daß wasser auf die Mühl zu führen, gentzl.: abgelaßen, wordurch solch Teichel an den hechten, darinnen denen.1. scholck gestanden, schaden genohmmen, vnd auf die 50. stuck weg Kommen, wie es aber mit den strich Teicheln beschaffen, Kan man noch nicht wissen.
# _________________________________________________
# Der hoff Müller Geörg Wendwich hat den alten Lehen Strich Teich Vntter dem Scholtzen, in der dörren Zeit, mit wasser Zu der Mühlen nicht gehalten, Weylandt solcher Teich an der Ehe an dem 1. Scholck gestanden, Vnd etwan 50. Kopf entlauffen, die gelegenheit mit dem Strich Teich aber noch nicht Zu erwißen.
# _________________________________________________
# Time for test point 10: 1.78 seconds, Total time: 29.31 seconds
# Processing test point 11 of 1000
# _________________________________________________
# George Augstens hinderlaßen wittibe zue Raspenaw Claget Vber Maz Richtern daselbsten, das ehr sie hette deibstahlt beziehen, samb sie einen weiber Rock, vnd Muze gesohlen, wie sie auff ihnen gedrungen, vnd solches von ihme wollen erwiesen haben, wehre ehr ihr bis auff des Scholzen grundt, vnd boden nachgelauffen, vnd ihr beide Armen aus geschlagen, auch sie sonsten an ihrem leibe Soh zuschlagen, das side braun, vnd blaw wehre, Item ehr hette darnach vber den Aun gericht, vnd ihr einen Zahn im halse loß gesohsen, welches der Scholze gesehen, berichtet darneben auch sie hette den Scholzen vmb Gottes willen geben, ehr wolle sie laßen besichtigen, ehr hette es aber nicht thun wollen, sondern gesagt, sie solte es nur im Ambt Clagen das sie Köndten den Maz Richter nicht Zwingen darauff berichtet ehr Maz Richter, ehr wehre am Sontage bey seinem bruder geweßen, wie ehr hingeangen wehre Paul Neuman bej dem Stäge gesganden, vnd gefraget, wo seine hausgenoßein wehre, darauff ehr gesagt, sie ist zue Christoff Schracken gezogen, darauff ehr der Paul Neuman gesagt, sie hat ein wenig Knotten bej mir ausgeschuttet, vnd habe in deßen einen weiber rock, vnd muze vorlohren, hastu nichts bej ihr gemerkct, ehr darauff geandtworttet, ich habe nichts gemercket, solches hette ehr den dienstag hernacher seiner hausgenoßin den George Augsteinin Tochter, so bej ihme noch zu hauße gewesen, angemeldet, Nemblich ich habe von Paul Nauman gehoret, das ehr einem weiber rock, vnnd weiber muze vorlohren, vnd weil deine mutter in denselb. Cammer Knotten gehabt, hat ehr die Vormuthung, also wan deine mutter dieses genommen, hier aüff die Tochter des morgens Fruhe auffgestanden, zu ihrer mutter gelaufen, vnd ihr daßelbe also angemeldet, darauff wehre die alte Augsteinin vor seinen garten Kommen, bey dem Zaun gestanden, vnd geschrien, Fiebigs Maz du schalckz, vnnd schlmen, solches auch Vber.10. mahl widerholet, das ehr sie gebeten, sie sollte still schweigen, sie hette aber es vielmehr getrieben, darauff ehr sie mußen schlagen, gestehet gahr nicht, das ehr sei Sieben mahl zue erden geschlagen, sondern sie wehre Vber einen Zaun gestiegen, vnd daran hengen vorblieben, nachmals also gefallen, Sie hette in einem ihare etliche herbergen gehabt, dan ihres lohsen Vnnuzen mauls halb. wolte sie niemand beherbergen ehr hette gebehten, der Schultes wolle sie besichtigen, sie aber hette sich nicht wollen besichtigen laßen, christoff Vlrich hette sie ihres Vnnuzen mauls halben auch schlagen mußen, Auff beuohrstehenden Sonabendt sol sie wiederumb gestellen, nebenst andern
# _________________________________________________
# George Augstenin hinterlaßenen Wittib Zue Raspenaw Claget Vber Maz Richter daselbsten, das ehr sie beschuldiget sie hette ein Weibes Rock Vnd muze gestohlen, wie sie ihn Vber dießes ermahnet Vnd ihnen solches erweisen wollen, wehre ehr ihr nachgegangen bis auff des Schulteß grunde, Vnd auff baide arm geschlag.n, auch anderst auff den leib so Viel geschlag.n das sie schwarze Vnd blaw geweßen, Item nachmals hette ehr Vber die Zäune gegriffen, Vnd ihr einen Zahn aus der Kiefer gestohßen, so der Schulteß gesehen, Item berichtet sie auch das sie dem Schulteßen Vmb Gottes willen gebeten, sie zu besichtigen, ehr aber solches nicht thun wollen, Sond.n gesagt sie soltte es im Ambt Klagen, dan sie Maz Richtern nicht ermahnen Könen, darauff ehr Maz Richter berichtet, ehr wehre am Sontag bej seinem bruder geweßen, wie ehr dahin gang.n wehre Paul Nauman bej den stegen gestanden, Vnd gefraget, wo seine haußfraw wehre, darauff ehr gesagt sie wehre auff Christoff Schrackes Kommen, darauff ehr Paul Nauman gesagt, sie hette auff mein hauß ein wenig Knotten geschüttelt Vnd darbej eine weibes Rock Vnd weibes muze verlohr.n, hastu nichts mit ihr gesehen, ehr geandtworttet, ich habe nichts gesehen, die Mittwoch hernach hette ehr seiner haußfraw George Augsteinin Tochter, so noch bej ihme auffm hause geweßen, gesagt, als hette ehr Von Paul Nauman gehöret, das ehr eine weibes Rock Vnd weibes muze verlohren, Vnd weil deine Mutter im Kammern gehabt, giebet ehr vor, das deine Mutter solche genommen, hierauff die Tochter fruhe am morg. gelaufen Zue ihrer Mutter, Vnd solches ihr gesagt, darauff die alte Augsteinin Vor sein garten Kommen gestanden, bej der Zäune gestanden Vnd geschrien, Fiebiges Maz du schelm Vnd Schelm, dießes mehr als Zehen mahl gethan, das ehr sie Vorschrien, sie aber es Viel mehr gethan, darauff ehr sie schlagen mußen, gestehet nicht das ehr sie Zue erden sieben mahl geschlagen, Sond.n sie wehre Vber die Zäune gestiegen, Vnd an der selb.n gehangen, Vnd nachmals also gefallen, sie hette etliche schüttel im ihar gehabt, weil sie ihres lose mauls halben niemandt sie schütteln wollen, hette ehr den Schulteßen gebeten sie zu besichtigen, sie aber sich nicht besichtigen wollen, Christoff Vlrich hette auch sie weg. ihres lose mauls geschlagen, soll auffn Kunftig. Sonnabendt sich neben andern gestellen.
# _________________________________________________
# Time for test point 11: 13.78 seconds, Total time: 43.08 seconds
# Processing test point 12 of 1000
# _________________________________________________
# Die Soldaten contribution aufn Monatt Marty, Vom Angesessenen Zue 54: Kr.: außgeschrieben, Vnuerlangt ins hochGräffl.: Ambt abzuführen.
# _________________________________________________
# Die Soldaten contribution aufn Monat March, Zu 54. k. auf ein angeseßenen vorschrieben, Vnverlengt ins hochGräffl. Ambt abzuführen.
# _________________________________________________
# Time for test point 12: 0.87 seconds, Total time: 43.95 seconds
# Processing test point 13 of 1000
# _________________________________________________
# Demnach der herr Mgr Vnd Superintendens in Friedlandt sich Vber beide seine wiedmuths Pauren Zue Ringenhain Zumb höchsten beschweret, wie das sie sich in beschickung seiner wiedmuth sehr Vnuleißig erweiseten, derowegen Vmb andere Zwene Pauren, so ihme das seinige beschicken mochte, Als seind ihme Michel Schubart, Vnd George Ruger daselbsten angewiesen worden, welche die Wiedmuths äcker Vnd andere Fuhren aufs beste möglich. zubeschicken Vnd zu vorrichten zugesagt.
# _________________________________________________
# Demnach h. Magister Vndt superintendent Zu Friedlandt sich Vber seine beide Wiedemuths Pauren Zu Ringenhain hoch beschweret, das sie ihme seine wiedemuth sehr Vnflaissig beschäftigten, dahero ihme zwei ander Pauren Zu den glebe Zu Pflügen zugeschafft worden, so dan Michel Schubart Vndt George Ruger daselbst, so die wiedemuths felder Vndt and. Fuhrn als gutt möglich. pflügen Vndt verrichten sollen.
# _________________________________________________
# Time for test point 13: 2.25 seconds, Total time: 46.20 seconds
# Processing test point 14 of 1000
# _________________________________________________
# Martin vogel der alngeschneider von Hainersdorff, demnach vnnd Als er etlich geldt wegen der Burggraffen Georg von Seliger Gutt erlegen hette sollen vnnd Barttel Vlrich. Pürge dafur werden, Solch geldt aber von ihme noch von Pürgen biß auf dato nit erleget, derohalben sie baide gefenglich eingezogen vnnd Zu Pürgen wieder heraußgeben, derogestaldt vnnd Also das sie das Geldt Innerhalb 14 tage richtig ins Ampt erlegen sollen, oder aber sich herein ins Ambt Zuegestellen, Bey der Peen 50 sßo dafur Pürge vor Martin Vogell Anthonius Zweidler von hainerßdorf, Vor Barttel Vlrich, Nickel Vogell von heinnerßdorff, Signatum denn 7 Augustiy S.o 93.
# _________________________________________________
# Martin Vogel der Schneider von Hainerßdorff hat etzlich geldt von dem burggraffen Georg. V. Seligern gutte herruhren sollen, Vnd Bartel Vlrich hat Vor ihme burglich eingesezt, Solche gelder aber biß dato von ihme noch V. dem burgen nit gezahlet, derenthalben sie baide in gefengliche hafft eingezogen, deßelben aber widrumb entlediget, das sie das geldt in Vierzehen tagen ins Ampt einstellen, od. sich in Ampt gestellen sollen, bey der Peen Funffzigk schogk, der Purge Vor Martin Vogeln ist Anthonius Zweydelr Von Hainerßdorff, Vor Bartell Vlrichen ist Nickel Vogel Von Hainerßdorff, Signat: den 7 Augustij A.o 93.
# _________________________________________________
# Time for test point 14: 3.48 seconds, Total time: 49.68 seconds
# Processing test point 15 of 1000
# _________________________________________________
# Weiln hernach bemelte Schulteßen, an gestrieg gehaltenen Ambtstage, anbefohlenermaßen, Vnnd bei Vermeidung der Außgesetzten straff, nicht Er schienen; Alß soll Ein Jeder folgende straffgelder erlegen, so bej denen Renthen in gehöriegen Empfang Zu bringen
# _________________________________________________
# Weiln hernach bemeldte Schultheißen, an der gestrigen gehalttenen Ambtstage, vff befehlte Peen, nicht erschienen; Alß soll ein ieder nachstehende Straff gelder er legen, so in die Renthen in gehörige Einnahmb gebracht werden.
# _________________________________________________
# Time for test point 15: 1.34 seconds, Total time: 51.01 seconds
# Processing test point 16 of 1000
# _________________________________________________
# Hans winiger von Mildenaw. Demnach er in den gerichten Zu Rückerßdorff gefruelt mit der wehr muttwilliger weiße hereumb gefochten vnd gehauen, hat angelobt inerhalb acht agen ain weise schockh in ampt Zur Peen ein Zustellen, darfur Pürge Balthasar Hübner Von Rückerßdorff, Sig: den 8 January A.o 86.
# _________________________________________________
# Hans winiger von Mildenaw. Demnach er In den gerichten Zue Rückersdorf gefreuelt mit der Wehr Vmb sich gehauen, hat er angelobet In Acht tagen 1 Weiß schock ins Ampt Zur straf einstellen Burge Balthas hübner Von Rückersdorf, Sig: den 8 Januarij A.o 86.
# _________________________________________________
# Time for test point 16: 1.54 seconds, Total time: 52.55 seconds
# Processing test point 17 of 1000
# _________________________________________________
# Dato den 10. 9br. ist Christ: Vllrich nebenst obgedacht. 4. Personen so Zu bezahlung der Vncosten condemnirt worden nochmahlen herein erfordert, vnd die sach also ganzlichen erörtert worden: Namblich daß Christoph hoffman vnd Gregor Elßner, weiln dise beede am meisten schuldig, Zu ihren vorhin bezahlten 6 rthlr für ein faß bier dem Schultzen ein Jedweder noch 1 rthlr vnd dann den Jacob Elßner vnd Geörg Rossel auch Jedwed. 1. rthlr dar zu geben vnd also dem Scholtzen die 10. rthlr vncosten gänzliche entrichten der Christoph vllrich aber 5. rthllr, die er selbsten in wehrender rechtfertigung außgelegt fallen lassen soll: Jedoch der gesalt, dz wofern er Vllrich od. die andern auff dem hanß Rossel darbring. könn. daß er daß gelde nicht verlohren, sollen von dem selben alle vndt Jeder expensen gänzlich ersezt werd. Vnd tist darbej Zue allem vberfluß von dem Chr. Vllrich von oberwehnten seinem gegethail, in dem sie vorm Ambte außgesagt, dz sie weder in disem noch ainigem andern ihm nichts vnehrliches nachzusagen wüsten, sein Ehrlich. nahm wied. gegeb. word.
# _________________________________________________
# Heut dato den 10. 9br. ist Christ: Vllrich nebst obbemelten.4. Persohnen welche die Vnkosten entrichtung. schuldig. worden, nochmahlen herein beschieden worden, Vnd die sachen also gänzlichen beschieden worden, Nemblichen, das Christoph hoffman Vnd Gregor Elßner, weiln diese beede die meist schuldig, nebst der vor dießem Vorgelaßen.6. Rthl. dem Schultzen noch ein. Rthl. Vor ein faß bier Vnd dan Jacob Elßner Vnd Geörg Rossel als iedes. Rthl. Vnd also die.10. Rthl. Vnkosten dem Schultzen gänzlich bezahlet werden sollen. Christoph Vllrich aber.5. Rthl. laßen fallen, so ehr selbsten im gerichtliche gang Vorgelaßen, doch dergestaldt, wofern ehr Vllrich Von hanß Rossel erwaisen Kan, das ehr das geld nicht Vortauschet, soll alles Vnd iedes Vnkosten durch denselb. gänzlich wieder bezahlet werden. Vnd als dan in aller Vberschüßigkeit Chr. Vllrich von obbenandten beclagten, in deme sie bej dem Ambt ausgesagt, das sie ihme an dießen oder anderer Vrsachen nichts Vnbeschämtes nachzusagen wißen, Vnd ihme sein ehrennamb wiederumb erwehret worden.
# _________________________________________________
# Time for test point 17: 6.32 seconds, Total time: 58.87 seconds
# Processing test point 18 of 1000
# _________________________________________________
# Es beclaget sich hans Canz, wie ehr auf den nehen mittwoch gahr spath anheimb Komen, Vnd hette seiner Tochter ihme fallen Vmb ein groschell bier holen, Vnd wie sie auf der gaße gangen, wehre der lange Pfeiffer ihr hernach gang. sie eine hurr gescholtten, vnd zu boden geschlagen, do wehre das maglein anheimb geschrieen Kommen, Nach dießen aber Wehre ehr gang., vnd den alten Schultheßen zu Meffersdorf, so es geseh., gefraget, ob seine Tochter auch Vrsach darzu geb. hette, sie gesaget, nein, do wehre Caspar francke auff ihnen zu Kommen der lange Pfeiffer einen speiß erwischet auf ihnen Zugelaufen, ihme denselb. andie brust gesazt, nachmals aber ihnen zu boden geworffen Vnd hette ihnen Vmbs leb. bracht wan nicht leute ihme wehren zuhülfe Komen, hette auch sein weib zuboden geschlagen, der schade wehre augenscheinlich. Wagen Knecht wendet Vor, ehr hette ihme große Vrsach geben, Weill aber die Zugen Zue Neuwstadt so dießer halben angeben Worden, in den gerichten daselbste Vorhöret word., Welche unanimiter außag. das ihme der Schneider, Weibe, Vnd Tochter Zuuiel geschehen, Vnd das anfenglich., das megdel Keine Vrsach geben, Sond.n als ehr sie offters Vor eine hure gescholten hette sie gesagt, ehr mochte so lange ein schelme sein, bis daselbe erwiesen würde hierauff ehr sie also baldt zuboden geschlagen Seind hierauff beide Caspar Franck, Vnd WagKnecht in Kraußen gestackt Worden, bis auff ferneren beschaidt. heute dato denn.4. Septembris Anno.1612. ist Nicoll WagenKnecht den gefenglichen hafft Keg. einstellung.10. sso derogestald hinweiderumb entlediget Worden, das ehr sich Keg hanßen Canizen, seinem weibe Vnnd Tochter hinführen schiedtlichen Vnd friedtlichen Vorhalten solle, wirdt ehr aber sich an ihme Vorgreiffen soll ehr nebenst harter gefengnus.50. sso. straf, der herschafft erlegen. Bürge habe sich Vor ihnen eingelaßen Bartell Scholtze, moller Zumb Einsiedell hans Scholtz zue Newstadt, Vnnd Matz Rullrich wagner in friedlandt. das baderlohn sollen sie beide der wagenknecht Vnd Christoff Francke. Vor Caspar Francken burge Bartell Scholtz hans Scholtze, Vnnd Christoff Francke, Caspar Franckens Vater. haben auch selbsten bej höchstenn landtrecht angelobet, sich schiedtlich, Vnnd Friedlich Kunfftig Zuuorhaltten. Sig.m Friedlandt. ut Supra..NB. denn.12. Septemb. Ao. 1612. seindt auf der Boheimisch. Newstadt, hans Caniz, sein weib Vnd Tochter, sowohl Caspar Franck Vnd Nicol Wagen Knecht dergestaldt Vorglichen Worden, das sie beide das Artzlohn, als.4 1/2 Taler erleg. sollen, Zwisch. hier, Vnd Michäelis, hab. es einander mit handt Vnd munde abgebehtenn Wollen Forthin Friedlich Vnd schiedtlichen leben, hat Caniz gelichfals bej.50. sso strafe angelobet benebenst weib Vnd Tochter dieser also steif vnd fest nachzuleben, die Vncosten werd. beiderseits aufgehoben.
# _________________________________________________
# Hans Caniz Claget, wie ehr am Mittwoch sehr spath nach hause kommen Vnd seine Tochter ein groschen bier holen laßen, do wehre sie im garten gang.n, der lange pfeiffer ihr nach gelauffen, sie Vor eine hure gescholten, Vnd Zue boden geschlag.n, do wehre die medel nach hause geschrien, Nach dießem wehre ehr aber zu der alten Scholtzin Zue Mefferßdorff gang.n, so es gesehen, ob sein tochter auch Vrsach gegeben, gesagt, nun wehre Caspar Francke darzu kommen, Lange pfeiffer ein steckel gesehen, auf ihnen zu gestanden, nachmals ihnen Zue boden geworffen, Vnd ihme das leibes nehmen wollen, wan ihnen die leüthe nicht Zu hulffe kommen wehren, auch sein weib Zue boden geschlag.n, die schaden Zue sehen. Wagenknecht wendet Vor, ehr hette ihm große Vrsach gegeben. Weil aber die Zeugen auff der Neustadt, so in dießes Vortrag. gesezt, in der gerichten daselbsten abgehöret, Vnd einiglich. außgesagt, das ihme dem Schneider, sein weib Vnd tochter Vnrecht geschehen, Vnd das anfengs die medel Keine Vrsach gegeben, Sond.n wan ehr sie Vber Vnd Vber Vber eine hure gescholten, do hette sie gesagt ehr wehre ein Schelm so lang ehr solches nicht erweisen, darauff ehr sie also baldt Zue boden geschlag.n. Hierauff seindt beide Caspar Franck Vnd wagenknecht in Kraußen gestackt worden, bis auff ferner bescheidt. Heute dato den 4. Septembris A. 1612 Ist Nicol Wagenknecht der gefengnus entlediget worden Vmb erlegung 10 sso. der gestaldt, das ehr sich gegen Hans Caniz, sein weib Vnd tochter künfftig, schiedlich Vnd friedlich Vorhalten soll, Wan ehr ihnen aber angreiffen solte, soll ehr nebenst harter gefengnus der herrschafft 50 sso. strafe erlegen. Bürgen Vor ihne eingelassen, Bartell Scholtz Müller Zue Einseidel, Hans Scholtz auff der Neustadt, Vnd Matz Rullrich wagner Zue Friedlandt. der baderlohn soll sie beide geben, der Wagenknecht Vnd Christoff Franck. Vor Caspar Francken ist burge Bartell Scholtz, hans Scholtze, Vnd Christoff Francke, Caspar Francks Vater. Haben sich auch beym hochsten landes recht angelobet, Künfftig schiedlich Vnd friedlich Vor sich zuhalten. Sig.m Friedlandt ut Supra. N. p. den 12. Septembris A. 1612, seindt in Böhmisch. Neustadt, Hans Caniz, sein weib Vnd tochter, so wohl Caspar Francke Vnd Nicol Wagenknecht dahin Vortrag. worden, das sie beiderseits den arztlohn, als 4 1/2 taler, Zwischen hier Vnd Michäelis erleg. sollen, Haben einander mitt handt Vnd Mundt abgebehten, wollen Künfftig friedlich Vnd schiedlich Vor sich Vorhalten, der Caniz hat gleichsamb bej straff 50 sso. angelobet, nebenst weib Vnd tochter dießes fest Vnd gestendig. zu Volgen, die Vncosten seindt auff beide seiten auffgehoben.
# _________________________________________________
# Time for test point 18: 16.26 seconds, Total time: 75.14 seconds
# Processing test point 19 of 1000
# _________________________________________________
# Herr George leibnern Richtern Vnnd hanßen Plumberg betreffende in Friedlandt.
# _________________________________________________
# Wegen lord George Leibners Richters Vndt hanßen Plumbergs Zu Friedlandt.
# _________________________________________________
# Time for test point 19: 0.46 seconds, Total time: 75.59 seconds
# Processing test point 20 of 1000
# _________________________________________________
# Demnach Ich hauptman Vernohmen, das die beede Zu waigßdorff Wohnende herrn Vom Adel Alß herr Erasmus Von Gerßdorff, Vndt Christoph Friederich Von Schwanz, Ihnen Vor genohmen hetten, den 24.ten Marty diß Jahres die Kirchen rechnung daselbst abzunehmen, Zu halten, Vndt waß der notturfft darbej zu expediren. Weiln aber solcher actus dem Alten herkommen Vndt Verträgen Zum höchsten Nachtheil Vndt praejudiz, nicht weniger zu schmälerung deß habenden Juris Collaturi schnur stracks Zu wieder laufet, Alß habe Ich herrn Capitan Leutnanten Johann Bernhardt Von döbern auf Waigßdorff, Vnnd hießiger herrschafft Renthschreibern h. heinrich Wilhelmen Neuman, obbedeüten tag nacher waigßdorff Zu oberwehnten herrn beeden Vom Adel geschicket, Vnd auß habenden gn. befehl, auch ratione officy, wieder solch Vnberechtigtes Vndt Vnbefugtes Vornehmen, in bester formb Rechtens waß hier Zu requirirlich, Solonnißime protestiren, Vndt alle darwieder
# _________________________________________________
# Nachdeme ich haubtman, Vernommen, daß sich die beede von Adel auf Waigßdorff wohnhafftig, Alß herr Erasmus von Gerßdorff, vndt Christoph Friederich von Schwanz, Sub Dato den 24.ten Martij dieses Jahres, Vnterstanden, die Kirchen Raittung daselbsten abzunehmen, vndt die dazugehörige nötigeßes zu besorgen: Weiln aber solcher Act zu dem hochst. Vnngleich. vndt praejudicium der Alten gebrauch vndt contract, vndt zu der Juris Collaturi, so besitzt, nicht geringern schadet, Alß habe ich h. Capitan leutnanten Johann Bernhardt von döbern auf Waigßdorff, vndt des herrschaffts Renthschreiber h. heinrich Wilhelmen Neumanen, ut Supra, den Vorgenambten 24.ten Martij auf Waigßdorff, zu obbesagten Zweyen herrn von Adel, p. zu besuch., vndt auß gnediger befehl, vndt auch ratione Officy, solchem vngebuhrten vndt vnrechtmeßigen Vnternehmen, in bester form der Rechtswissenschaft hierin bedorfften, solenniter Protestiren, vndt alle rechtliche Notturft
# _________________________________________________
# Time for test point 20: 5.95 seconds, Total time: 81.54 seconds
# Processing test point 21 of 1000
# _________________________________________________
# Nickel Möller Schulteß Zue dittersbach, demnach Vnd Alß er hanß scholtzen Vnd Christoff scholzen geheissen sie solten barttel Neuman Wol zu schlagen Vnd Vf Vielfaltige befehl Jörg Rüdeln Vnd Christof fibigern niemals herein gesteld sint sie derenthalben gefenglich. Eingezogen worden Vnd Zu Pürgen wiederumb außgeben, der gestald Vnd Also das er sich Wann er gefordert wirde gestellen solle, bey der Peen 50 sß dafur Ist Purge Matz Weise schulteß Zu hermßdorff Signatum Friedlandt den 7 10bris A. 91.
# _________________________________________________
# Nickel Möller Schultes Zum ditterspach, demnach vnd Alß er hanß scholtzen Vnd Christoff scholtzen gesagt sie solten bartell Neumann wol schlag. Vnd Auf offtes befehl Jörg Rüdel Vnd Christof fibigern nit gestellen, derenthalben sie gefenglich eingezogen Vnd Zu Purg wieder herauß geben, der gestaldt Vnd Also das er sich Auf erfoderung sich gestellen soll bey der Peen 50 sß, dafür Purge Matz weise schultes zu hermßdorff, Signat: Fridlandt den 7 decemb A. 91.
# _________________________________________________
# Time for test point 21: 2.72 seconds, Total time: 84.25 seconds
# Processing test point 22 of 1000
# _________________________________________________
# Georg Redes von luesdorff hat bürgen gesazt in Achtagen das guett zuuerkauffen, dafern er in achtag. solch guet nit verkauffen haben sich vor In bürglich eingelassen Michel Barckman vnd Marttin Röslers von luesdorff, In wiederumb herin In die gefengnus Zu gestellen, Friedlandt den 11 Februarij Ao. 97.
# _________________________________________________
# Georg redes von lusdorf hat burgen gesazet, das er das gutt in acht tagen vorkauffen wil, so fern er das gutt in acht tagen nit vorkaufft, haben sich vor ihn burglichen eingelaßen Michel barckman vnd Marttin Rössler von lusdorf, ihnen wid. herein in gefengnuß gestellen, Signat: Fridlandt den 11 February A.o 97.
# _________________________________________________
# Time for test point 22: 1.83 seconds, Total time: 86.08 seconds
# Processing test point 23 of 1000
# _________________________________________________
# Chrhistoph Kraußen Scholzen von Wayspach, wirdt verlaubet, das er sich mit des Christoph Paßigs Garttnern daselbst Ehelichen Tochtern Vrsula, Verhewrathen möge.
# _________________________________________________
# Christoph Kraußen Scholzen von wayspach ist erlaubet, sich mit Christoph Paßigs Gärtners daselbsten Ehelichen Tochter Ursula Zuverehelichen zuverehlichen.
# _________________________________________________
# Time for test point 23: 0.91 seconds, Total time: 86.99 seconds
# Processing test point 24 of 1000
# _________________________________________________
# Wie oben den 20. July zusehen, ist Zwischen Christoph Teichmanen Vndt Geörg Langen Ein Vergleich geschehen, Weiln nun der Lange Zu dem Teichman Vnnlengst auf Offentlicher straßen gesagt, daß Er Vor Ihme den hudt vnter die Augen gezogen, hatt ihme hiengegen der Teichman die Schalckstücke de novo vor geworffen: Vnnd weiln sie beede Vnnrecht befunden, soll ieder 1. sßo. Geldes Zuer straff geben, Seindt mit 5. sßo. Verpeent. p.
# _________________________________________________
# Wie obige den.20. Julij zwischen Christoph Teichmanen Vndt Geörg Lang. sich ein Vergleich beschlossen, Weiln Lange nunmehr Teichmanen auff der Offentlichen Strassen gesagt, Er habe ihm die Mütze Vnter die Augen gezogen, Teichman wiederumb wieder ihn die schelmerey erheben, Vndt Weiln sie beede Vnrecht befunden, soll ieder.1. sßo. gelt Zur straff erlegen, Sindt mit.5. sßo. straff Verbürget.
# _________________________________________________
# Time for test point 24: 2.35 seconds, Total time: 89.34 seconds
# Processing test point 25 of 1000
# _________________________________________________
# Heinrich Von Temeriz kam abgeschaidter beschweret sich weg. Christoff Waltern so bej deme Von debschiz ezliche gelder zufordern Bittet weill Vor abschiedet worden, das die austzehlung derselb. auß drej Vntterschiedene termin abgezehlet werd. sollen, Vnnd der erste Termin ahn izo fellig, Bittet ehr der Walter das die austzahlung ahn izo Zureuck gerichtet werd. möge
# _________________________________________________
# Heinrich Von Temeriz ist auf erfoderung Kommen, sich Vber Christoff waltern, welcher etlich geldt bey dem Von Debschiz Zufordern, beklagt, pittet weil es rechtlich beschieden, das ausgabe selbiger auf drey Vntterschiedene Termin solte ausgelegt werden, Vnd der erste Termin an izo Vorfallen, pittet ehr der walter, das ausgabe izo wiederumb gelegt werden mochte.
# _________________________________________________
# Time for test point 25: 1.95 seconds, Total time: 91.29 seconds
# Processing test point 26 of 1000
# _________________________________________________
# Jörg Lindner von Mildenaichen demnach er dem Scholtzen ohne alle gegebne vrsach an seinem aignen Haus gefodert: vnd die Fabian Lindnerin die möllerin an ihren Ehren geschmecht, Ist Zu Pürgen außgeben, das er sich wan vnd Zu welcher Zeit er gefodert bey verlust 20 schockh gestellen soll, darfur sint Pürgen Marcus Roßler vnd Christoff Weste von Lußdorff, Sig: den 16 January A.o 86.
# _________________________________________________
# Jörg lindner von der Milden Eichen, demnach er dem Scholzen ohne gegebene Vrsach auß seinem hause gehaissen, auch die Ehren der Fabian lindners Mollin weib geschmehet, Ist er der gestalt entlediget, das er sich auf erforderung wieder gestellen soll bey der Peen 20 sß darfur Pürge Marcus Rossler Vnd Christoff Westen Zu lußdorff, Signatum den 16 January A.o 86.
# _________________________________________________
# Time for test point 26: 2.08 seconds, Total time: 93.38 seconds
# Processing test point 27 of 1000
# _________________________________________________
# Demnach Zwischen Matheß Gärtnern vnd Hanß Apelten beeden Pauren deß Reinß Halben beides vor einem Jahr sich Einiger Streit erhoben, vnd dahero der gärtner bey selbigen Geirchten Klagende ein Kommen Alß haben sie die Reine Zwischen beede Güttern beaugenscheiniget die sachen in Richtigkeit gesetzet, vnd Alßo solchen Streit verglichen Vnd Weiln die Gerichten deß Halben viel bemßhungen vnnd Gänge gehabt, alß daß sie öffters in Kretschamb Zu sammen Kommen auch gewiße Zeugen von MargLißa darzu beruffen müßen auch selvige Gericht Eß schriefftlichen ertheilet, welches der Matheß Gärttner meistens verursachet. Alß seindt Gerichts: vnd andere Vnkosten biß in die 12 f. darauff ergangen, Zu welchen der Gärtner 7 vnd der Apelt 5 f. geben sollen, worauf ein ieder 2 f. entrichtet der Gärtner aber Hat seine restirende Parth nicht erlegen wollen, in Meinung eß geschehe ihm Zu viel, Weiln er aber der vergleich gutt geheißen, vnd seine VnKosten ab Zu Legen Gewilliget, alß beleibt eß auch nochmahlen darbey: daß der Rest von beeden theilen Nembl. der Gärtner 5 f. vnndt der Apetl auch seine 3 f. erlegen soll, vnd weiln der Gärtner auch die Zwischen ihnen gesetzte Pöen alß der gned. Obriegkeit 10 sß vnd der Gemeine 1/2 faaß bier Muthwilliger Weiße gebrochen, alß soll er solche auch erlegen vnd bezahlen, Vnnd ist über dießes ihnen Wiederumben eine Neue Poen benennet Nembl. gned. Obriegkeit 20 Rthlr: vnd 4 wochen einen Arrest do der Verbrechende theyl so dann abzulegen vnd außZustehen hat.
# _________________________________________________
# Demnach Zwischen Matheß Gärtnern Undt hanß Apelten beeden Pawern Vorm Jahr, Vnterschiedtliche strittigkeiten Vmb die Rein Entstanden, Vndt derentwegen der Gärtner in die Gericht daselbst Klagende einkommen, Als haben sie die Rein Zwischen beeden guttern Visuell besichtiget, die sache richtig gesezet, Vndt solche strittigkheit dahin Vortrag. gebracht, Vndt Weiln die Gerichten dießfahlß Viel Vntternehmben Vndt Kommen Vndt gehen gehabt, das sie offt im Kretschamb zusammen Kommen, auch gewiße Zeigen Von Marglißa dahin erfordern, Auch solches den Gerichten schriftlichen mitgetheilt, Welches Matheß Gärttner Vormöge VerVrsacht, Als seindt Gerichts Vndt andere Vnkosten daruon ausgegeben bis auf 12. darauf Gärtner 7 f Vndt Apelt 5 f er Legen sollen, Welches ieder 2 f erlegt, Gärtner aber seines Restes nicht geben wollen, Vnter dem Vorwande, es wurde ihme zuu vil gethan, Weiln er aber der Vergleich gutt Vndt seine Vnkosten bezahlen williget, Alß ist es auch noch darbej Verbleibet, das der Rest von beeden Partten gelegt werden soll, Nembl. Gärtner 5 f Vndt Apelt sein 3 f geben soll, Vndt Weiln der Gärtner auch die Zwischen ihnen gesezte Peen, Nembl. 10 sß der gn: Obriegkeit Vndt 1/2 faß bier der gemeine, Vnterbrochen, soll er auch solche erleg. Vndt bezahlen, Vndt Vber dießes ihnen nochmahlen eine neue Peen gesezet worden, Nembl. der gn: Obriegkeit 20 Rthler Vndt ein Arrest Vf 4 woch., Welchen der Verbrechende Parte dann zu bezahlen Vndt Vnterstehen soll.
# _________________________________________________
# Time for test point 27: 9.01 seconds, Total time: 102.39 seconds
# Processing test point 28 of 1000
# _________________________________________________
# Heute dato den 10 Septemb. seind her hanß Nußler Vnd George Simon Zu fridlandt ins Ambz Kommen, sich vber den Bergkhaubtman beschwert, das ob sie wohl ihr Zubuße, sobaldt ihnen die zubuß zettell zugeferttiget wurd., als bald erlegten, vnd an ihnen disfals Keinen mangeln spihren das den arbeitern Vnd Bergkleuten ihr richtig. Zechen gebührend. maßen vorgestand. wirde, Bitten, das disfals auf den Bergkhaubtman ein mußtes einsehen gehabt, Vnd enderung getroffen werden möchte, Solte dißes aber nicht eruolgen, wurden sie gezwung. ihre bergkteile liegz.laßen, Sie erinnern auch dießes darneben, das Viel zechen Verkaufft, Zubuß darauf gegeb. dießelb. aber in bewlich.n wesen nicht erhalten wirden, würden nicht allein die bewercken Vmb ihne ohnlange gebraucht, sondern der herschafft Zehend. gemercklich.n geringert, darmit man nun disfals hind. den grundt Kommen möchte, hielten sie vorrahtsamb, das mit Zuziehung des Bergkmeysters, man die Zechen nacheinander in augenschein nehmen, befragen, welche Vnnd wie starck dieselb. in bewlich. wesen gehalten, Vnnd also Kunfftig von frembden gewercken mit beßerem bericht begegnet werden möchtee.
# _________________________________________________
# Klag Hans Nüßlers Vndt Georg Simon. Hans Nüßler Vndt Georg Simon Von Friedlandt seindt ins Ambt Kommen, Vber den Bergkhaubtman geclaget, wie sie ihme die Zümblohn als baldt man ihnen die Zümblohn Zettel abgefertiget, Vndt Vmb sie Keine mangel befunden, das die Arbeith Vndt bergleute ihre gebürenden Zünß richtig bekommen, bitten, in diesem Vahl der Bergkhaubtman solte einsehen Vndt eine andern maßen machen, Vndt so er solches nicht thun, seindt sie gezwungen, ihre bergteile liegen lassen, Erinnern auch das sie Viel bergstollen Vorkaufft, Vndt Zümblohn daran geben, doch solche im Vortag nit gehalten, nicht alleine, sondern auch die herschafts Zünß mercklich. Vorminderung, das man in diesem Vahl hinter die grunde Kommen möchte, betreffen es Vorstehen, das mit bey teil des bergmeisters die stollen ein nach dem andern besichtiget, Vndt befraget werden solle, welcher Vndt in Wieviel solche Vortag gehalten, Vndt also Künfftig frembde bergwercke mit bessern nachricht angetroffen werden.
# _________________________________________________
# Time for test point 28: 5.71 seconds, Total time: 108.10 seconds
# Processing test point 29 of 1000
# _________________________________________________
# Christoff Nichts Zue Raspenaw hinderlaßner witib beschwehrung vber daß Außgeding, so auff Ihrem guett, nach berg des am 10 Marty Ao. 1627 getroffenen Kauffs, hafftet, vnd Ires seel. Mans Stieff Muettern Sara, weyl.: Jacob Nichtens nachgebliebener witib widerfahren solle, so lang sie lebt, Ist dato vor dem Ambt alhier, in beysein des Schulz. vnd Geschworner dahin moderiert vnd vermitelt worden, daß Ermelter Sara Nichtin fürtershin für dz ganze Außgeding, die vberscharr bis ans Trüch floß vnd das Fläckhel an der Eichen, mit darob erpawtem haüßlen, so lang sie lebt, Zue nuz. vnd Zue genüessen pleiben: das vberige Außgeding durchgehents auffgehoben: nach dern Tödlich. hindritt aber solliche vberscharr vnd Außgeding, widerumben ins Guett vnd dessen Inhabere fallen vnd Kommen solle, damit Christoff Nichts nachgelaßene witib mit Ihren Kindern, desto ehender einen Kauffman Zue dem Guett bekhommen: vnd die schuld. Zallen: alß Ihren Kindern einen nutzen schaffen Kenne vnd möge.
# _________________________________________________
# Christoff Nichts Zue Raspenaw Wittib Clage wegen des Außgedingten Renten Contrahets, auf ihrem gutte, welches nach dem Kauffe deß 10 Marty Ao. 1627 beruhet, vnd welches an ihres Mannes Stiefmutter Sara Jacob Nichts Wittib so lange sie lebet, zustendig sein solle, ist heut dato im Ambt alhier in beysein Schultz vnd geschwornen Vermittelt worden, daß gedachte Sara Nichtin künfftig Zum gantzen Renten Contrahet, den Vberschar biß zum Trückfloss, vnd die fläckhel zu den Eichen, mit dem darauf gebaueten häuslen so lange sie lebet, gebrauchen vnd geniessen solle, die andere Renten Contrahet aber ganz aufgehoben werden, Nach ihrem absterben aber solle dießer Vberscharr vndt Renten Contrahet zu dem gutte vndt dessen Würd. heimfallen, damit Christoff Nichts wittib mit ihren Kindern, das gutt eher verkauffen, die schuld. bezahlen, vnd die Kinder vorsehen können.
# _________________________________________________
# Time for test point 29: 4.82 seconds, Total time: 112.92 seconds
# Processing test point 30 of 1000
# _________________________________________________
# ...
# _________________________________________________
# Demnach er mit Gregor möllers tochter in vnzucht gelebt, derenthalben er in gefenglich hafft eingezogen, vnd zu Pürgen wiederumb aufgeben, dergestaldt das er vf der hern J. G: forwerg ainem, ain Jahr lang diehnen vnd sich innerhalb acht tagen ins dienst gestellen sol bej d. Peen 20 sß dar fur Pürger hans helbig Thomas helbig beyde von liewerda, Signatum den 27 July Ao. 87
# _________________________________________________
# Demnach er mit Gregor Möllers Tochter in unzucht gelebet, darumb er gefenglich eingezogen vnd zue Purgen wieder herauß geben worden, der gestaldt, das er ein Jahr lang auff des herrn forwerg dienen soll, vnd sich in die dienste in Achtagen gestellen soll bey der Peen 20 sß, dafür Purge hans helbig vnd Thomas helbig baide von liewerda, Signatum den 27 July A.o 87.
# _________________________________________________
# Time for test point 993: 2.07 seconds, Total time: 5050.43 seconds
# Processing test point 994 of 1000
# _________________________________________________
# Christof Köler Kompt Supplicando ein, daß weil Er Ihme ein Neu hauß Vnd scheune gebauet, aber Inwendig noch nit vollendts aus gebauet, daß Ihme doch Von gnädiger Obriegkeit holze waß darzu Verehret wirde. Beschaid. Weiln die Gerichten Zuegnüß geben, daß Supplicant sein Schune Vndt hauß New erbauet, Vndt alles holtz von gn. herrschaft darzu erkauffet, auch ferner nit Mittel habe solche gebeude Zuuorfertigen, Alß Wolle IHme h. Forstmeister Einen Stamholz zu brettern, Vnd 5. stämmell bauholz ohn Entgeld abfolg. lassen. Actum Schlos Friedland. d. 7. May ao. 1652.
# _________________________________________________
# Christof Köler Suppliciret, weil er sich ein neues hauß vnd Scheunen gebauet, solche aber innen gantz nicht außgebaudet, das er doch von der gnädigen Obriegkeit an etlichem holz gnschafftet werd. möchte. Beschaid. Weil die gerichte auß sagen, das Supplicant sein hauß vnd Scheunen neülich gebauet, vnd solche von gn: herrschafft alles holz gekaufft, auch zu ausführung solcher gebäude ferner nicht mittel hat, so wirt ihme von herrn Forstmeister 1 stambe an bretter vnd 5. stämme an bauholz, ohne bezahlung, ertheilet w.d. Actum Schlos Friedlandt, 7 May Ao 1652.
# _________________________________________________
# Time for test point 994: 3.47 seconds, Total time: 5053.90 seconds
# Processing test point 995 of 1000
# _________________________________________________
# Demnach bey Ihr Hoch Gräffl.: Gnad.: Meiner g.: Obrigk.: Mathes Gäbler Pachtman zu Görlietzheimb im winckel Supplicando ge horsambl.: ein Kommen, vndt gebethen, Ihm bey seinem Pacht Zettel, welchen herr Adam Carl von Olppeln daselbst in Vnterschiedenen Vndt Hernach Specificirten Puncten disputirlich machen thete, maßen das Supplicat Vndt dessen Von Oppeln schreiben Sub Nro 51: mit mehren besaget gnedig zu schützen undt zu manuteniren. Gestalten Ihr gnad.: mir auch deßen Memorial zu dem Ende zu gestellet, die sachen zu verHören, Vndt solche in Ruhe standt zu setzen als bien auch deme gehorsambl.: nachkommen wie Folgents mit mehren zu sehen. 1. das backen bleibt auf dem Kretschamb zwar, doch aber ist dem herrn nicht verwehret da durch des Gemeinen nutzen halber 1: oder zwey becken ein zu setzen. 2. der brandtweinschank, Lauth Pacht Zettels, bleibt dem Pachtman allein. 3. der bierschanck, deß gleichen, als auch die bier züge bleiben allein dem Pachtman, iedoch wann er Pachtman beFunden oder ertappet wirdt, daß er das bier verFältschet Haben solte, ist er dem herrn iedes mahlen zur Straf 10: Rthll Verfallen, damit aber Kein theil so whol der Gestrenge Fraw aufn Hof, wegen außgebung geringen biers halber noch dem Pacht scholtzen daß bier zu Ver fälschen einige schuldt zumeßen werden Könne, soll allemahl der Gerichts geschworne Mathes Wünsche bey dem bier außschroten sein, Vndt Von selbigen Fas oder Achtel die wohl gedachte Fraw dem Gedachten Pachtman als dem geschwornen, Ein oder Zwey gläßer daruon zu Kosten geben, Vndt nach deß geschwornen gewißen soll bedeutes bier auf allen Fahl Vndt bey etwann entstehenden streit geachtet werden.
# _________________________________________________
# Demnach Mathes Gäbler Pachtman Zue Görlizheim, bej Ir. Gn: Gnd: Meiner gnädigen Obrigkheit p. Petition gebeten, Vndt gebeten, Ihn mit seinem Pachtbrieff, so herr Adam Carl Von Olppeln daselbsten in einigen, nachstehenden puncten disputiren, Vndt Supplicanten Vndt des von Oppelns schreiben solches in mehrer Außführung beschreiben, in Schutz Vndt behaltten Zu laßen, Als hat Ir. Gn: auch mich in sein memoriam dahin Zu gerichtet, die sachen Zu Verhören, Vndt in Ruhe Zu bringen, Als habe ich solches gehorsamblichen Volget, wie nach Volgender maßen in Außführung. 1. das Backen, Restiret beim Krezschemb, Jedoch dem herrn nit Vorbotten, 1 oder 2 Bäcken, wegen des Allgemeinen nutz einzuführen. 2. das brantwein, folget dem Pachtman alleine, 3. das bier, ebenfahls, wie auch das bier Aus schröten, Restiret dem Pachtman alleine, da er aber Pachtman, mit dem bier, Vnter die Augen gerathen, oder betroffen werden solte, soll er dem herrn Jedes mahlen 10 Rthl. straff erleg., damit aber Einiger Partt, weder die Fraw in der Gericht Vmb das schlechte bier, noch der Pachtman Scholtze, mit dem bier falschen, in Einem oder dem Andern, vorwerffen können, soll Einmahl die Gerichts geschworne Mathes wünsche bej dem bier Außschroten, bey sein, Vndt Von dem selbigen faß oder Achtel, soll die Wolgeehrte Fraw, gedachten Pachtman, Vndt auch die Geschworne, Ein oder Zwey glaß, darvon proeffen, solcher bier, soll die geschworne, ihres gewißen nach, in allen fällen, Vndt in Jeder stritt, die beurteilen.
# _________________________________________________
# Time for test point 995: 9.20 seconds, Total time: 5063.10 seconds
# Processing test point 996 of 1000
# _________________________________________________
# Ich Johan friederich genter, der beeden Graff Gaallasischen Herrschafften friedlandt vnd Reichenbergk, verordneter Hauptman, vhrkhunde mit dießer attestation vor Jedermänniglichen, insonderheit wo es von nöthen, daß die wohlEhrwürdige, in gott geistliche Patres Societatis Jesu, herr Pat: Casparus Brauerg. Casparus Hildebrandt, adamus Lindner, Adamus Creutziger Joannes Lautterbach, Zacharias maltzer, andreas Kuhn, Joannes Walter, Laurentig beck, daniel Friderig, Joannes Heineman et Heinricus pohl, von anfang deß heyl. reformations,, wert vnd gehalten mission bey hießig. mir ampts anvertrauten Herrschafft fridlandt, bey stadt vnd landt, Zeit ihres Hier seins, ihn ihren aufgetragenen geistlichen ämtern vnd officys, sich ieder Zeit embßig, fleißig, vnverdroßen, alls treuen geistlichen vndt Seel sorgern geziemet, Verhalten vnd bezeiget, ein guttes exemplarisches leben, vnd vnsträflichen wandel gefuhret, in Summa lles fleißigst beobachtet, so zue erabau: vnd mehrung der h.en Catholischen, allein Seligmachenden religion nutz: vndt ersprießlichen geweßen, allermaßen Hieran die sämptlichen beambten, vnderthanen vndt Inwohner, ihrem ertheilten warhafften Zeugnuß nach, bemelter dießer herrschafts firedlandt, ein sathsames vndt gefälliges genugen getragen, vndt noch Lenger wohl sehen vndt Haben mögen, in consideration es Zue großen nutz vnd nehmung der heyl. catholischen religion gereihet hette. dahero meiner obligirten schuldigkeit noch dießes schriefftliche Testimonium in ueritatem rei Hiermiterthailen, vndt mit meiner aigen handt vnd.schrift vndt gewöhnlichen petschafft bekräfftigen benebenst der gantzen hochlöbl. Societet in dehro gebeth vndt sacrificien, Hießige mir ampts anvertraute Herrschafft friedlandt, mich vndt die meinigen bestens recommendiren vndt gefließenst befehlen wollen. Geben auf den Graff Gallasischen schloß Fridlandt. den 2 octob. 1657.
# _________________________________________________
# Ich Johan Friederich Geuter, der beeden Gräffl.: Gallaßischen herrschafften Friedlandt vndt Reichenbergk, Verordneter haubtman, certificire mit dießer Attestation Vor alle Persohnen, insonderheit wo solches probiren wirdt, daß die sehr Erwehnte, Gottselige Geistlichen Vätter der Gesellschaft Jesu, herr Vätter Casparus brauer, Casparus hildebrandt, Adamus Lindner, Adamus Creutziger, Joannes Lautterbach, Zacharias Maltzer, Andreas Kuhn, Joannes Walter, Laurentig Beck, Daniel Friderig, Joannes heineman, Vnndt Heinricus Pohl, von Anfang der Heyl. Reformation auf der herrschaft Friedlandt alhier, so mir an meines Ambt, in Stadt Vndt Landt, Vbergeben, in die Zeit ihres alhier geweßen seyns, in den ihnen anvertrauten geistlichen Ambt, allzeit eifern, fleißig, Vndt Vnvergesslich Vorhalten, als beuor gebührender getreuer Geistlichkeit Vndt Seelenpflegern, ein guttes Exempellig. Leben Vndt Vnsträffliches Leben gelebt, Vndt in summire alles fleißig beobachtet, was zu aufbau Vndt erhebung der Heyl. Catholischen allein Seelig machenden Religion, nützlich Vndt fruchtbar geweßen, den gesamten ambtsleüthen, Vnterthanen Vndt Inwohnern, nach ertheilten wahrheits getruhen Vortzeigung, der gedachte herrschafft Friedlandt, genugsamb Vndt begehrensamb Vorbracht, Vndt wol sehen, Vndt noch Lenger Vber sehen wollen, in ansehung daß es Zu grosser nutz Vndt annehmung der Heyl. Catholischen Religion gelangt. Alß befehlte meines schuldigen dienstes, dießes schriftlichen Vortzeigung in Vrithem Rej Vber dißes Vndt eigenhändig. Vnterschrifft, Vndt gewöhnlich. Vntterschlag, Vndt will die mir anvertraute, hießige herrschafft, mich Vndt meine Familie, der gantz gelobten Gesellschaft zu ihren beten Vndt geopfer, mit solcher Vntterschreibung, befehlte, Vndt Vnterschriebene, Vndt Vnterschlagte, Vntterschafft, Vndt Vntterschrifft, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte, Vntterschlagte,  ...
# _________________________________________________
# Time for test point 996: 106.42 seconds, Total time: 5169.52 seconds
# Processing test point 997 of 1000
# _________________________________________________
# Mertten hüeküff Claget sich Vber Wilrich Hebrigen wie ehr den in seine behaüßung wie seiner tochter hochzeit geweßen, Komen, die Schußeln Vber Tische geworffen, wie sein schreyben vnd clage vormag.
# _________________________________________________
# Mertten Hüeküff Claget Vber wilrich hebrigen, wie ehr in sein hauß Kommen, als sein tochter HochZeitt geweßen, hette die schalen Vber den Tisch geworffen, wie sein schreyben Vnd Clage besaget.
# _________________________________________________
# Time for test point 997: 1.19 seconds, Total time: 5170.71 seconds
# Processing test point 998 of 1000
# _________________________________________________
# Erhart Fuchß Sattler ist H. George Frantzeln Zumb Seidenberg gestendiger schuldt schuldig 4 Tal. 18 g. Vor halbe Tonen Heringe, Vnnd 16 arg. Vor wein Vortuncken Bittet Vmb Zahlung.
# _________________________________________________
# Erhart Fuchß Sattler ist lord George Frantzeln zu Seidenberg schuldig 4 Tal. 18 g. an einer halben Tonnen heringe, vnd 16 Arg. vmb wein so er getruncken, bittet Vmb Zahlung.
# _________________________________________________
# Time for test point 998: 1.12 seconds, Total time: 5171.84 seconds
# Processing test point 999 of 1000
# _________________________________________________
# Denn 25. Martij Ist hanß Krichoff für mich erfordert wordten, Ist Zwar d. schuldt gestendig, abe sich dabey Zum hochsten beschweret dz die Hering nit voll gewesen, hat Er doch Zue gesaget, die Wochen nach Ostern diß 1627. Jarß Zuzahlen.
# _________________________________________________
# Den 25. Martij ist hanß Krichoff Vor mich erfordert, so er der schuldt gestendig, Hat er doch Clagende Vorlautet, die heringe seien nicht vol, hat aber Zugesagt, die wochen nach Ostern iezo Ao. 27. Zuzahlen.
# _________________________________________________
# Time for test point 999: 1.27 seconds, Total time: 5173.11 seconds
# Processing test point 1000 of 1000
# _________________________________________________
# Christof Neuman Zu Bullendorff. Claget, dz Er Jacob Sigmundten daselbst sein gut verkaufft In d. Summa P. 198 sß. den neuen geldte, hierauff hette Er bekommen 54 sß. vnd verblibe Ihme noch Zuzahlen 144 sß. so Jehrlich. mit 18 sß sollen abgeleget werden, mit welcher Zahlung Er gleichwoll aufgezog. würde, Pittet derentweg. vmb hülffe. Jacob Sigmundt berichtet, dz Er dz gut in obigem wert Kaufft, wehre aber an neuen geldte geschehen, vnd wehre Im vnmüglich., In dem Valor Zuzahlen, Pittet vmb Linderung, Weiln aber auf bericht d. gerichte, souill vernomben, dz es ein geringes gutt, vnd zu teuer verkaufft, Alß ist es mit bed. Personen dahin gemittelt worden, dz d. Sigmundt dem Neuman vor obgemelte 144 sß Zahlen soll 96 sß. vnd solche 96 sß Jehrlichen mit 12 sß alß anfenglich. auf Pfinsten 1627 biß Zu endtlicher bezahlung allemall auf Pfinsten mit 12 sß. ablegen soll. geschehen Actum vt Supra.
# _________________________________________________
# Christof Neuman Zu Bullendorff. Claget ehr habe ihme Jacob Sigmundt daselbsten sein gutt Vorkaufft Vmb 198 198 sso. newes geldes darauff ehr 54 sso. bekommen Vnd noch ihm restiren 144 sso. so iharlich mit 18 sso. solten abgelegt werden, mit welchen ablegung ehr Vortzogen wurde, Bittet derowegen Vmb hülffe. Jacob Sigmundt berichtet ehr habe das gutt Vmb obige Summa erkhaufft, wehre aber im new geldt geschehen, Vnd Vnmöglichen wehre in dießer wertt zu zahlen, bittet Vmb linderung. Weill aber auff bericht der gerichte, sich befund., das es ein arme gutt, Vnd Vber teürt Vorkaufft wehre, Als ist es beiderseits dahin mittellet worden, das Sigmundt dem Neuman Vor obige 144 sso. 96 sso geben, Vnd dieße 96 sso iharlich mit 12 sso ablegen sollen als auffn Pfingsten Ao. 27 Vnd solche ablegung bis auff endtliche Zahlung geschehen.
# _________________________________________________
# Time for test point 1000: 5.25 seconds, Total time: 5178.36 seconds
# Dataset saved successfully to /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Meta-Llama-3.1-8B-Instruct-bnb-4bit/finetuning/EN_to_DE/EN_to_DE_finetuning.json
