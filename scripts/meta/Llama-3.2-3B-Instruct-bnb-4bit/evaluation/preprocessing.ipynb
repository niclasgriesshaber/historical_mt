# %% [markdown]
# # Import libraries

# %%
import os
import re
import pandas as pd
from functools import reduce

# %% [markdown]
# # Set Paths

# %%
# Base path
base_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..', '..', '..'))

# Model Parameters
unsloth_model_name = 'unsloth/Llama-3.2-3B-Instruct-bnb-4bit'
company_name = 'meta'
model_name = unsloth_model_name.split('/')[1]

# %%
# Results directory path
results_dir = os.path.join(base_path, 'results', company_name, model_name)

# List of shot values

shots_list = [2**i for i in range(8)] 
shots_list.insert(0, 0)
#shots_list = [] # change for finetuning

# Print paths
print(f'Base path: {base_path}')
print(f'Results directory: {results_dir}')
print(f'Shots list: {shots_list}')
# Out:
# Base path: /cs/student/msc/csml/2023/ngriessh/historical_mt
# Results directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit
# Shots list: [0, 1, 2, 4, 8, 16, 32, 64, 128]

# %% [markdown]
# # Function to Load JSON Files into DataFrames

# %%
def load_json_to_df(folder_path, direction, shot):
    """
    Load JSON files into a DataFrame, rename columns, and handle missing data.

    Parameters:
    - folder_path: Path to the folder containing the JSON files.
    - direction: 'DE_to_EN' or 'EN_to_DE'.
    - shot: An integer for shot number or 'finetuning'.

    Returns:
    - A pandas DataFrame with the loaded data.
    """
    # Construct file and column names based on 'shot'
    if isinstance(shot, int):
        formatted_shot = f"{shot:03}"
        file_name = f"{direction}_{formatted_shot}_example_prompt.json"
    elif shot == 'finetuning':
        file_name = f"{direction}_finetuning.json"
    else:
        print(f"Invalid shot value: {shot}")
        return pd.DataFrame()

    file_path = os.path.join(folder_path, file_name)

    # Check if the file exists and load data
    if os.path.exists(file_path):
        print(f"File exists: {file_path}")
        try:

            # Read the JSON file into a DataFrame
            df = pd.read_json(file_path, lines=True)

            # Remove 'text' column if it exists
            df.drop(columns=['text'], inplace=True, errors='ignore')

            return df
        
        except ValueError as e:
            print(f"Error reading JSON file {file_name}: {e}")
            return pd.DataFrame()
    else:
        print(f"File does not exist: {file_path}")
        return pd.DataFrame()

# %% [markdown]
# # Load and Merge DataFrames

# %%
# Initialize an empty list to hold DataFrames
dataframes = []

# Loop through folders and shots to load data
for direction in ['DE_to_EN', 'EN_to_DE']:
    for shot in shots_list: # + ['finetuning']: # change for finetuning
        
        # Determine base folder ('finetuning' or 'icl')
        base_folder = 'finetuning' if shot == 'finetuning' else 'icl'
        folder_path = os.path.join(results_dir, base_folder, direction)
        print(f"\nProcessing directory: {folder_path}")

        df = load_json_to_df(folder_path, direction, shot)
        if not df.empty:
            print(f"Loaded data for direction '{direction}', shot: {shot}")
            dataframes.append(df)
        else:
            print(f"No data loaded for direction '{direction}', shot: {shot}")
# Out:
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_000_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 0
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_001_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 1
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_002_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 2
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_004_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 4
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_008_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 8
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_016_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 16
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_032_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 32
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_064_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 64
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_128_example_prompt.json
# Loaded data for direction 'DE_to_EN', shot: 128
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_000_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 0
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_001_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 1
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_002_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 2
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_004_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 4
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_008_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 8
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_016_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 16
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_032_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 32
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_064_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 64
#
# Processing directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE
# File exists: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_128_example_prompt.json
# Loaded data for direction 'EN_to_DE', shot: 128

# %% [markdown]
# # Merge All DataFrames

# %%
# Merge all DataFrames on 'English' and 'Early Modern Bohemian German' columns
if dataframes:
    # Perform an outer merge to combine all DataFrames
    merged_df = reduce(lambda left, right: pd.merge(
        left, right, on=['English', 'Early Modern Bohemian German'], how='outer'), dataframes)
    print("\nAll DataFrames merged successfully.")
    
    # Perform an inner merge to find matches across all DataFrames
    matches_df = reduce(lambda left, right: pd.merge(
        left, right, on=['English', 'Early Modern Bohemian German'], how='inner'), dataframes)
    num_matches = matches_df.shape[0]
    print(f"Number of matches across all DataFrames: {num_matches}")
else:
    merged_df = pd.DataFrame()
    print("\nNo DataFrames to merge.")
# Out:
# All DataFrames merged successfully.
# Number of matches across all DataFrames: 1000

# %%
# Check column names
merged_df.columns
# Out:
# Index(['Early Modern Bohemian German', 'English',
#        'DE_to_EN_000_example_prompt', 'DE_to_EN_001_example_prompt',
#        'DE_to_EN_002_example_prompt', 'DE_to_EN_004_example_prompt',
#        'DE_to_EN_008_example_prompt', 'DE_to_EN_016_example_prompt',
#        'DE_to_EN_032_example_prompt', 'DE_to_EN_064_example_prompt',
#        'DE_to_EN_128_example_prompt', 'EN_to_DE_000_example_prompt',
#        'EN_to_DE_001_example_prompt', 'EN_to_DE_002_example_prompt',
#        'EN_to_DE_004_example_prompt', 'EN_to_DE_008_example_prompt',
#        'EN_to_DE_016_example_prompt', 'EN_to_DE_032_example_prompt',
#        'EN_to_DE_064_example_prompt', 'EN_to_DE_128_example_prompt'],
#       dtype='object')

# %% [markdown]
# # Define Column Order and Reorder DataFrame

# %%
# Define the column order
column_order = ['Early Modern Bohemian German', 'English']

# Append DE_to_EN columns
de_to_en_columns = [f"DE_to_EN_{shot:03}_example_prompt" for shot in sorted(shots_list)]
de_to_en_columns.append("DE_to_EN_finetuning")
column_order.extend(de_to_en_columns)

# Append EN_to_DE columns
en_to_de_columns = [f"EN_to_DE_{shot:03}_example_prompt" for shot in sorted(shots_list)]
en_to_de_columns.append("EN_to_DE_finetuning")
column_order.extend(en_to_de_columns)

# Reorder the DataFrame columns
existing_columns = [col for col in column_order if col in merged_df.columns]
merged_df = merged_df[existing_columns]

print("\nColumns in the merged DataFrame:")
merged_df.columns.tolist()
# Out:
# Columns in the merged DataFrame:
# ['Early Modern Bohemian German',
#  'English',
#  'DE_to_EN_000_example_prompt',
#  'DE_to_EN_001_example_prompt',
#  'DE_to_EN_002_example_prompt',
#  'DE_to_EN_004_example_prompt',
#  'DE_to_EN_008_example_prompt',
#  'DE_to_EN_016_example_prompt',
#  'DE_to_EN_032_example_prompt',
#  'DE_to_EN_064_example_prompt',
#  'DE_to_EN_128_example_prompt',
#  'EN_to_DE_000_example_prompt',
#  'EN_to_DE_001_example_prompt',
#  'EN_to_DE_002_example_prompt',
#  'EN_to_DE_004_example_prompt',
#  'EN_to_DE_008_example_prompt',
#  'EN_to_DE_016_example_prompt',
#  'EN_to_DE_032_example_prompt',
#  'EN_to_DE_064_example_prompt',
#  'EN_to_DE_128_example_prompt']

# %% [markdown]
# # Clean merged_df

# %%
# Function to clean text entries
def clean_text(text):

    # Remove unnecessary double white-spaces
    text = re.sub(r'\s{2,}', ' ', text)

    # Remove line breaks
    text = re.sub(r'[\n\r]+', ' ', text)
    
    # Remove unnecessary spaces before punctuation
    text = re.sub(r'\s+([.,;!?])', r'\1', text)
    
    # Fix spacing around apostrophes (replacing ’ with ')
    text = re.sub(r'\s+’\s+', r"'", text)
    
    # Fix double spaces or unnecessary whitespace
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# %%
# Apply clean_text to each column in merged_df
for column in merged_df.columns:
    merged_df[column] = merged_df[column].apply(lambda x: clean_text(str(x)))

# %%
# Drop NA values and count how many 'NA' or missing values are dropped
na_values_removed = merged_df.isin(['NA', None]).sum()
merged_df = merged_df.replace('NA', None).dropna()

# Trim whitespaces and remove line breaks
merged_df = merged_df.map(lambda x: x.strip().replace('\n', '') if isinstance(x, str) else x)

# Reporting the number of 'NA' or missing values removed
print('NA values removed:', na_values_removed)
# Out:
# NA values removed: Early Modern Bohemian German    0
# English                         0
# DE_to_EN_000_example_prompt     0
# DE_to_EN_001_example_prompt     0
# DE_to_EN_002_example_prompt     0
# DE_to_EN_004_example_prompt     0
# DE_to_EN_008_example_prompt     0
# DE_to_EN_016_example_prompt     0
# DE_to_EN_032_example_prompt     0
# DE_to_EN_064_example_prompt     0
# DE_to_EN_128_example_prompt     0
# EN_to_DE_000_example_prompt     0
# EN_to_DE_001_example_prompt     0
# EN_to_DE_002_example_prompt     0
# EN_to_DE_004_example_prompt     0
# EN_to_DE_008_example_prompt     0
# EN_to_DE_016_example_prompt     0
# EN_to_DE_032_example_prompt     0
# EN_to_DE_064_example_prompt     0
# EN_to_DE_128_example_prompt     0
# dtype: int64

# %%
# Check merged_df
merged_df.head()
# Out:
#                         Early Modern Bohemian German  \
# 0  1. dz Sie verschienen freytag als den 29 huig ...
# 1  Es ist Vor.12. iharen Vnnd mehr Zu Oberweigßdo...
# 2  3. Novembris. Matz Apelt beschweret sich Vber ...
# 3  Adam Kötter von d. Wittige, demnach er sich mi...
# 4  Adam Krauß zumb Einsiedel saget auff sein gewi...
#
#                                              English  \
# 0  1. last Friday, the 29th, they came up to the ...
# 1  12 years ago and more, in Oberweigsdorf, Paul ...
# 2  3. Novembris. Matz Apelt complains against Jac...
# 3  Adam Koetter from the Wittige, since he disput...
# 4  Adam Krauss in Einsiedel declares on his consc...
#
#                          DE_to_EN_000_example_prompt  \
# 0  They arrived on the 29th day in great haste to...
# 1  It is before the 12th of April in Oberweigßdor...
# 2  November. Matz Apelt complains about Jacob Sch...
# 3  Adam Kötter von der Witte, according to whom h...
# 4  Adam Krauß says on his oath that he has sworn,...
#
#                          DE_to_EN_001_example_prompt  \
# 0  The village headman of Friedland, named Hans N...
# 1  It is before the 12th of January and more to O...
# 2  November. Mathias Apelt complains about Jacob ...
# 3  The village headman of Wittige, according to w...
# 4  Adam Krauß says on his oath, I will do it upon...
#
#                          DE_to_EN_002_example_prompt  \
# 0  They appeared free on the 29th day of high in ...
# 1  It is before the 12th of January and more to O...
# 2  The complainant, Matz Apelt, complains about J...
# 3  Adam Kötter from Wittige, since he has been im...
# 4  Adam Krauß to Einsiedel says, upon his oath, t...
#
#                          DE_to_EN_004_example_prompt  \
# 0  They arrived freely on the 29th of high day at...
# 1  It is reported. 12 years ago and more To Oberw...
# 2  November. Matz Apelt complains about Jacob Sch...
# 3  Adam Kötter from Wittige, since he has quarrel...
# 4  Adam Krauß says to his wife about what has hap...
#
#                          DE_to_EN_008_example_prompt  \
# 0  They arrived freely on the 29th of high day in...
# 1  It is before the 12th of their own and more to...
# 2  The 3rd of November. Matz Apelt complains agai...
# 3  The village headman of Wittige, since he had q...
# 4  Adam Krauß says on his oath, that he wishes to...
#
#                          DE_to_EN_016_example_prompt  \
# 0  They arrived freely on the 29th of high in gre...
# 1  It is known that Paul Appelt, deceased in Ober...
# 2  On 3 November, Matz Apelt complains about Jaco...
# 3  Adam Kötter from Wittige, since he had with Ur...
# 4  Adam Krauß says on his oath, that he wishes to...
#
#                          DE_to_EN_032_example_prompt  \
# 0  They arrived freely on the 29th of high in gre...
# 1  It is reported that Paul Apelt, deceased in Ob...
# 2  On 3 November, Matz Apelt complains against Ja...
# 3  Adam Kötter from the witty, since he with Ursu...
# 4  Adam Krauß says on his oath, that he wishes to...
#
#                          DE_to_EN_064_example_prompt  \
# 0  They arrived freely on the 29th of high in gre...
# 1  It is reported that Paul Apelt, who has been d...
# 2  3. Novembris. Matz Apelt complains against Jac...
# 3  Adam Kötter from the Wittige, since he quarrel...
# 4  Adam Krauß says to his confession, that he int...
#
#                          DE_to_EN_128_example_prompt  \
# 0  1. That you appeared on the 29th of high day a...
# 1  Paul Apelt, who died on the 12th of their ance...
# 2  3. November. Matz Apelt complains against Jaco...
# 3  Adam Kötter from the Wittige, since he with Vr...
# 4  Adam Krauß from Einsiedel says that he intends...
#
#                          EN_to_DE_000_example_prompt  \
# 0  1. Am letzten Freitag, dem 29sten, kamen sie z...
# 1  Zwölfig Jahre und mehr zuvor in Oberweigsdorf ...
# 2  Dreizehnter November. Matz Apelt klagt gegen J...
# 3  Adam Koetter von dem Wittigen, weil er in Wort...
# 4  Adam Krauß in Einsiedl spricht auf seiner Gewi...
#
#                          EN_to_DE_001_example_prompt  \
# 0  Der Schulteß Zu Friedland, kam zu dem Burhause...
# 1  Zwey jahre und mehr zuvor in Oberrhegisdorf is...
# 2  Dreys Ember Maii. Matz Apelt klagt wider Jacob...
# 3  Der Schultheß zu Witte, hat Adam Kötter von de...
# 4  Adam Krauß zu Einsiedl spricht auf seiner Gewi...
#
#                          EN_to_DE_002_example_prompt  \
# 0  1. Gestern Freitag, der 29ten, kamen sie in gr...
# 1  Twelff Jahre vorher und mehr in Obergerwitz, i...
# 2  Dreynembris. Matz Apelt klagt gegen Jacoeb Sch...
# 3  Adam Koetter von der Wittige, demnach er in Wo...
# 4  Adam Krauß in Einsiedel bekennt sich auf sein ...
#
#                          EN_to_DE_004_example_prompt  \
# 0  1. Gestern Freitag, den 29ten, kamen sie in gr...
# 1  Twelff Jahre und mehr in Oberweygsdorf ist Pau...
# 2  Dreissigste November. Matz Apelt klagt gegen J...
# 3  Adam Koetter von Wittig, demnach er mit Ursula...
# 4  Adam Krauß in Einsiedel, auf seiner Gewissen d...
#
#                          EN_to_DE_008_example_prompt  \
# 0  Von Freitag, den 29. Maien, kamen sie in große...
# 1  Twelff Jahre und mehr, in Obergerwiesdorff, Pa...
# 2  Drei Novembres. Matz Apelt klaget gegen Jacobi...
# 3  Adam Koetter von Wittige, demnach er mit Worte...
# 4  Adam Krauß in Einsiedel, auf seiner Gewissheit...
#
#                          EN_to_DE_016_example_prompt  \
# 0  Dem Tagt Friddays, den 29. Octobris, kamen sie...
# 1  Vor 12 jaren und mehr in Obergerweigsdorf ist ...
# 2  Dem 3. Novembris. Matz Apelt klaget gegen Jacc...
# 3  Dem Adam Koettert Zu Wittig, da er in Worten s...
# 4  Dem Adam Krauss in Einsiedel, auf seiner Gewis...
#
#                          EN_to_DE_032_example_prompt  \
# 0  Dem Tagelichsten Freitag, den 29. September, k...
# 1  Vier Jahre und mehr Vorher in Oberschleißheim ...
# 2  Dem 3. Novemb. Matz Apelt klaget gegen Jaccho ...
# 3  Demnach Adam Koetter Zu Wittig, weil er mit Wo...
# 4  Dem Adam Krauss in Einsiedel, auf seiner Gewis...
#
#                          EN_to_DE_064_example_prompt  \
# 0  Der Herrscher Zu Friedlandt kam am letzten Fre...
# 1  12 jahre und mehr Vorher in Oberweigsdorff sta...
# 2  Matz Apelt klaget Jacob Schwedtner, weil er si...
# 3  Adam Koetter Von der Wittige hat angelobt, das...
# 4  Adam Krauss in Einsiedel klagt auf seiner Gewi...
#
#                          EN_to_DE_128_example_prompt
# 0  Demnach sie alle zu dem Schloss Fridland in gr...
# 1  Der alte Paul Apelt in Oberweigsdorff ist 12 j...
# 2  Demnach Matz Apelt Zu Friedlandt Klaget gegen ...
# 3  Adam Koetter Von der Wittige, demnach er mit U...
# 4  Adam Krauss in Einsiedel beclagt auf seiner Ge...

# %% [markdown]
# # Save the Merged DataFrame

# %%
# Save the merged DataFrame to a JSON file
output_file = os.path.join(results_dir, "merged_results.json")
merged_df.to_json(output_file, orient='records', lines=True, force_ascii=False)

print(f"\nMerged DataFrame saved to {output_file}")
print('Done!')
# Out:
# Merged DataFrame saved to /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/merged_results.json
# Done!

# %% [markdown]
# # Summary of Paths Used

# %%
print("\nSummary of Paths Used:")
print(f"Base path: {base_path}")
print(f"Results directory: {results_dir}")
print(f"Output file: {output_file}")

print("\nData directories and file checks:")
for direction in ['DE_to_EN', 'EN_to_DE']:
    for shot in shots_list + ['finetuning']:
        base_folder = 'finetuning' if shot == 'finetuning' else 'icl'
        folder_path = os.path.join(results_dir, base_folder, direction)
        if isinstance(shot, int):
            formatted_shot = f"{shot:03}"
            file_name = f"{direction}_{formatted_shot}_example_prompt.json"
        elif shot == 'finetuning':
            file_name = f"{direction}_finetuning.json"
        else:
            continue  # Skip invalid shot values
        file_path = os.path.join(folder_path, file_name)
        file_exists = os.path.exists(file_path)
        print(f"File: {file_path} - Exists: {file_exists}")
# Out:
# Summary of Paths Used:
# Base path: /cs/student/msc/csml/2023/ngriessh/historical_mt
# Results directory: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit
# Output file: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/merged_results.json
#
# Data directories and file checks:
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_000_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_001_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_002_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_004_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_008_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_016_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_032_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_064_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/DE_to_EN/DE_to_EN_128_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/finetuning/DE_to_EN/DE_to_EN_finetuning.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_000_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_001_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_002_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_004_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_008_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_016_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_032_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_064_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/icl/EN_to_DE/EN_to_DE_128_example_prompt.json - Exists: True
# File: /cs/student/msc/csml/2023/ngriessh/historical_mt/results/meta/Llama-3.2-3B-Instruct-bnb-4bit/finetuning/EN_to_DE/EN_to_DE_finetuning.json - Exists: True
